# %%
import json
from src.pipeline.processor import PipelineProcessor

processor = PipelineProcessor(source_dir="data/unprocessed")

feedback = json.loads(open("data/feedback/feedback_batch_01.json").read())

result = processor.run(feedback=feedback, evaluate_pending=True)
print("Ingested:", result["ingestion"].success, "Failed:", result["ingestion"].failed)
print("Evaluations:", len(result["evaluations"]))

analysis = processor.run_analysis(limit=50)
# Out:
# Ingested: 0 Failed: 0
# Evaluations: 11
# DEBUG: Analysis discovery found 21 evaluations with issues out of 21 reviewed.
# DEBUG: Clustering 39 granular issues...
# DEBUG: Enriching cluster 1/9 with LLM reasoning...
# DEBUG: Enriching cluster 2/9 with LLM reasoning...
# DEBUG: Enriching cluster 3/9 with LLM reasoning...
# DEBUG: Enriching cluster 4/9 with LLM reasoning...
# DEBUG: Enriching cluster 5/9 with LLM reasoning...
# DEBUG: Enriching cluster 6/9 with LLM reasoning...
# DEBUG: Enriching cluster 7/9 with LLM reasoning...
# DEBUG: Enriching cluster 8/9 with LLM reasoning...
# DEBUG: Enriching cluster 9/9 with LLM reasoning...
# DEBUG: Discovery phase identified 9 distinct failure patterns.
# DEBUG: Generating improvement proposal for pattern: 'Guidance Failure Post-Error' (Significance: 70.0)
# DEBUG: Generating improvement proposal for pattern: 'Inadequate Response Engagement' (Significance: 22.5)
# DEBUG: Generating improvement proposal for pattern: 'Non-Grounded Parameter Usage' (Significance: 52.5)
# DEBUG: Generating improvement proposal for pattern: 'Date Format Mismatch' (Significance: 18.0)
# DEBUG: Generating improvement proposal for pattern: 'AI Agent Execution Failures' (Significance: 37.5)
# DEBUG: Generating improvement proposal for pattern: 'Flight Booking Missteps' (Significance: 52.5)
# DEBUG: Generating improvement proposal for pattern: 'Tool Call Failure' (Significance: 7.5)
# DEBUG: Generating improvement proposal for pattern: 'Excessive Latency Spike' (Significance: 8.0)
# DEBUG: Generating improvement proposal for pattern: 'Name Memory Lapse' (Significance: 4.0)
# DEBUG: Analysis cycle complete. Generated 9 proposals.

# %%
analysis
# Out:
# [ImprovementProposal(proposal_id='49ea292e-628d-4f3d-b31e-c81c4558a3c8', type=<ImprovementType.PROMPT: 'prompt'>, cluster_id='e20613b6-9e60-4117-a939-b65c2c904be4', failure_pattern='The core technical cause is likely a poor error-handling mechanism that fails to offer corrective suggestions or effective next steps after encountering a date format error.', rationale='The proposed change directly addresses the lack of error handling for date format errors. By instructing the AI to offer users a suggestion on the correct date format and prompting them to re-enter the information, the snippet enhances the user experience by providing clear guidance on how to resolve the issue. This localized change does not alter or disrupt other functionalities of the system prompt.', original_content='You are a helpful travel assistant. Use tools when necessary.\n', proposed_content='You are a helpful travel assistant. Use tools when necessary. If you encounter a date format error, provide the user with a suggestion on the correct date format to use and ask them to enter the date again.', evidence_ids=['tool_regression_001', 'latency_edge_001', 'disagreement_001', 'tricky_low_conf_001', 'demo_pipeline_1766773293392', 'demo_pipeline_1766773293392', 'demo_pipeline_1766773415101', 'demo_pipeline_1766773415101', 'demo_pipeline_1766774333209', 'demo_pipeline_1766774333209'], status=<ProposalStatus.DRAFT: 'draft'>, regression_report=None, created_at=datetime.datetime(2025, 12, 26, 22, 24, 59, 929539), updated_at=datetime.datetime(2025, 12, 26, 22, 24, 59, 929540), metadata={'confidence': 0.9, 'prompt_path': 'artifacts/prompts/prompt_v1.txt', 'tool_schema_path': 'artifacts/tools/tool_schema_v1.json', 'artifact_version_hint': 'v1'}),
#  ImprovementProposal(proposal_id='3794b5f1-663a-43fd-9a83-b77d7c1ce334', type=<ImprovementType.PROMPT: 'prompt'>, cluster_id='29de3164-5a8e-4706-b389-4e335ac111c2', failure_pattern='The core technical cause is likely insufficient context understanding or inadequate response generation algorithms, leading the AI to fail in producing comprehensive or engaging replies.', rationale='The proposed snippet emphasizes not just helpfulness but also being knowledgeable and engaging, which addresses the systemic failure of producing comprehensive or engaging replies. This change encourages the AI to provide more detailed and interesting responses, enhancing the overall user experience while keeping the existing functionality intact.', original_content='You are a helpful travel assistant. Use tools when necessary.\n', proposed_content='You are a knowledgeable and engaging travel assistant who provides detailed travel information and suggestions. Use tools when necessary.', evidence_ids=['tool_regression_001', 'latency_edge_001', 'disagreement_001'], status=<ProposalStatus.DRAFT: 'draft'>, regression_report=None, created_at=datetime.datetime(2025, 12, 26, 22, 25, 2, 260408), updated_at=datetime.datetime(2025, 12, 26, 22, 25, 2, 260411), metadata={'confidence': 0.85, 'prompt_path': 'artifacts/prompts/prompt_v1.txt', 'tool_schema_path': 'artifacts/tools/tool_schema_v1.json', 'artifact_version_hint': 'v1'}),
#  ImprovementProposal(proposal_id='9991d5aa-a845-4c2b-a08d-c010e17d593e', type=<ImprovementType.TOOL: 'tool'>, cluster_id='c4d72ce1-fc50-47db-bb4e-ba1338b970dd', failure_pattern='The AI agent is using parameter values that have not been explicitly referenced in the preceding conversation, indicating a failure in context tracking or state management.', rationale='By adding parameter constraints with clear descriptions and validation patterns, the AI agent is guided to only consider input values that fit the expected types and formats. This improves context tracking by ensuring the agent interprets and uses parameters in alignment with predefined, explicit constraints. This addresses the systemic failure by preventing unintended or implicit parameter uses when not explicitly specified.', original_content='{\n  "required_params": [\n    "destination"\n  ],\n  "optional_params": [\n    "date",\n    "origin"\n  ]\n}', proposed_content='{\n  "required_params": [\n    "destination"\n  ],\n  "optional_params": [\n    "date",\n    "origin"\n  ],\n  "parameter_constraints": {\n    "destination": {\n      "type": "string",\n      "description": "The destination city or airport code for the flight."\n    },\n    "date": {\n      "type": "string",\n      "description": "The date of the flight in YYYY-MM-DD format.",\n      "pattern": "^\\\\d{4}-\\\\d{2}-\\\\d{2}$"\n    },\n    "origin": {\n      "type": "string",\n      "description": "The origin city or airport code for the flight."\n    }\n  }\n}', evidence_ids=['tool_regression_001', 'hallucination_001', 'causality_hallucination_002', 'happy_path_001', 'demo_pipeline_1766773293392', 'demo_pipeline_1766773415101', 'demo_pipeline_1766774333209'], status=<ProposalStatus.DRAFT: 'draft'>, regression_report=None, created_at=datetime.datetime(2025, 12, 26, 22, 25, 5, 471985), updated_at=datetime.datetime(2025, 12, 26, 22, 25, 5, 471992), metadata={'tool_name': 'flight_search', 'fix_category': 'validation_rule', 'prompt_path': 'artifacts/prompts/prompt_v1.txt', 'tool_schema_path': 'artifacts/tools/tool_schema_v1.json', 'artifact_version_hint': 'v1'}),
#  ImprovementProposal(proposal_id='646da920-3f94-494d-a90c-eb1d70593490', type=<ImprovementType.TOOL: 'tool'>, cluster_id='f0500e6e-3af7-4697-bd50-5a873814c6e5', failure_pattern="The 'check_in' parameter uses an incorrect date format 'DD/MM/YYYY' instead of the expected format, likely 'YYYY-MM-DD'.", rationale="The existing schema did not specify a format for the 'date' parameter, which could lead to incorrect date formats being used. By enforcing the 'YYYY-MM-DD' format through a proper JSON Schema format keyword, we ensure consistency and prevent errors related to date parsing.", original_content='{\n  "required_params": [\n    "destination"\n  ],\n  "optional_params": [\n    "date",\n    "origin"\n  ]\n}', proposed_content='{\n  "type": "object",\n  "properties": {\n    "destination": {\n      "type": "string",\n      "description": "The destination airport or city code."\n    },\n    "date": {\n      "type": "string",\n      "format": "date",\n      "description": "The desired date of travel in \'YYYY-MM-DD\' format."\n    },\n    "origin": {\n      "type": "string",\n      "description": "The starting airport or city code."\n    }\n  },\n  "required": [\n    "destination"\n  ],\n  "additionalProperties": false\n}', evidence_ids=['tool_regression_001', 'demo_pipeline_1766773293392', 'demo_pipeline_1766773415101', 'demo_pipeline_1766774333209'], status=<ProposalStatus.DRAFT: 'draft'>, regression_report=None, created_at=datetime.datetime(2025, 12, 26, 22, 25, 7, 845837), updated_at=datetime.datetime(2025, 12, 26, 22, 25, 7, 845843), metadata={'tool_name': 'flight_search', 'fix_category': 'validation_rule', 'prompt_path': 'artifacts/prompts/prompt_v1.txt', 'tool_schema_path': 'artifacts/tools/tool_schema_v1.json', 'artifact_version_hint': 'v1'}),
#  ImprovementProposal(proposal_id='fd5b5985-9e2e-4be3-ac21-d935bd30f1ab', type=<ImprovementType.PROMPT: 'prompt'>, cluster_id='f80e5339-d1ea-47de-8e78-ae60edfba090', failure_pattern='The core technical cause is likely a failure in the invocation or configuration of external APIs responsible for hotel and flight search functionalities.', rationale='The proposed change explicitly instructs the AI to ensure the correct setup and invocation of external APIs, which addresses the core technical issue causing the systemic failure. By adding a directive regarding the verification and configuration of APIs, it emphasizes the importance of these operations in carrying out hotel and flight searches successfully. This localized change does not alter the overall purpose of the prompt but enhances it to handle the failure pattern effectively.', original_content='You are a helpful travel assistant. Use tools when necessary.\n', proposed_content='You are a helpful travel assistant. Ensure to verify and correctly configure external APIs for hotel and flight search functionalities. Use tools when necessary.', evidence_ids=['tool_regression_001', 'hallucination_001', 'demo_pipeline_1766773293392', 'demo_pipeline_1766773415101', 'demo_pipeline_1766774333209'], status=<ProposalStatus.DRAFT: 'draft'>, regression_report=None, created_at=datetime.datetime(2025, 12, 26, 22, 25, 9, 994413), updated_at=datetime.datetime(2025, 12, 26, 22, 25, 9, 994414), metadata={'confidence': 0.85, 'prompt_path': 'artifacts/prompts/prompt_v1.txt', 'tool_schema_path': 'artifacts/tools/tool_schema_v1.json', 'artifact_version_hint': 'v1'}),
#  ImprovementProposal(proposal_id='f8c81cc4-2d29-487f-9cda-a88e909e52df', type=<ImprovementType.TOOL: 'tool'>, cluster_id='9951bc43-3642-418e-a772-4532b091ffe3', failure_pattern='The core issue is a combination of parameter mismatches and assumptions leading to incomplete or inaccurate flight search and booking processes.', rationale="The schema now includes 'origin' and 'date' as required parameters to ensure complete flight information is provided, preventing incomplete searches. The addition of 'return_date', 'passengers', and 'class' as optional fields allows for a more comprehensive search and booking process. Enhanced parameter definitions improve clarity and validation, which directly addresses parameter mismatches by enforcing correct data types and logical constraints.", original_content='{\n  "required_params": [\n    "destination"\n  ],\n  "optional_params": [\n    "date",\n    "origin"\n  ]\n}', proposed_content='{\n  "required_params": [\n    "destination",\n    "origin",\n    "date"\n  ],\n  "optional_params": [\n    "return_date",\n    "passengers",\n    "class"\n  ],\n  "param_definitions": {\n    "destination": {\n      "type": "string",\n      "description": "The airport code or city name for the destination."\n    },\n    "origin": {\n      "type": "string",\n      "description": "The airport code or city name for the origin city."\n    },\n    "date": {\n      "type": "string",\n      "format": "date",\n      "description": "The departure date in YYYY-MM-DD format."\n    },\n    "return_date": {\n      "type": "string",\n      "format": "date",\n      "description": "The return date for round trips in YYYY-MM-DD format."\n    },\n    "passengers": {\n      "type": "integer",\n      "minimum": 1,\n      "description": "The number of passengers traveling."\n    },\n    "class": {\n      "type": "string",\n      "enum": [\n        "economy",\n        "business",\n        "first"\n      ],\n      "description": "The class of service preferred for the flight."\n    }\n  }\n}', evidence_ids=['hallucination_001', 'hallucination_001', 'causality_hallucination_002', 'causality_hallucination_002', 'happy_path_001', 'happy_path_001', 'happy_path_001'], status=<ProposalStatus.DRAFT: 'draft'>, regression_report=None, created_at=datetime.datetime(2025, 12, 26, 22, 25, 15, 689884), updated_at=datetime.datetime(2025, 12, 26, 22, 25, 15, 689885), metadata={'tool_name': 'flight_search', 'fix_category': 'schema_fix', 'prompt_path': 'artifacts/prompts/prompt_v1.txt', 'tool_schema_path': 'artifacts/tools/tool_schema_v1.json', 'artifact_version_hint': 'v1'}),
#  ImprovementProposal(proposal_id='62d8f0ce-7a4c-4733-930a-2244d15db98b', type=<ImprovementType.TOOL: 'tool'>, cluster_id='c45f854f-6f14-4633-95f1-db0b69c7853b', failure_pattern='The core technical cause of this issue is improper tool integration, leading to incorrect or incomplete information being processed by the AI, thereby degrading response quality.', rationale="The systemic failure is likely due to the 'origin' and 'date' parameters being considered optional. Both 'origin' and 'date' are crucial for accurate flight searches, as flights typically require a starting point and a specific date to provide meaningful results. By making 'origin' and 'date' required parameters, we ensure that the AI agent has all the critical information needed to perform a comprehensive and accurate flight search. This change mitigates the risk of incomplete information leading to degraded response quality.", original_content='{\n  "required_params": [\n    "destination"\n  ],\n  "optional_params": [\n    "date",\n    "origin"\n  ]\n}', proposed_content='{\n  "required_params": [\n    "destination",\n    "origin",\n    "date"\n  ],\n  "optional_params": []\n}', evidence_ids=['hallucination_001'], status=<ProposalStatus.DRAFT: 'draft'>, regression_report=None, created_at=datetime.datetime(2025, 12, 26, 22, 25, 18, 144913), updated_at=datetime.datetime(2025, 12, 26, 22, 25, 18, 144914), metadata={'tool_name': 'flight_search', 'fix_category': 'schema_fix', 'prompt_path': 'artifacts/prompts/prompt_v1.txt', 'tool_schema_path': 'artifacts/tools/tool_schema_v1.json', 'artifact_version_hint': 'v1'}),
#  ImprovementProposal(proposal_id='9f400721-c699-4f50-a48d-4f34c78efc5f', type=<ImprovementType.PROMPT: 'prompt'>, cluster_id='1f2a8e42-93a6-4805-9653-3ace80f1345d', failure_pattern='The core technical cause is likely due to inefficient code execution or resource bottlenecks, leading to processing delays that exceed acceptable latency limits.', rationale="By adding 'highly efficient' and 'prioritize speed' to the prompt, I am directing the AI agent to focus on reducing processing delays and resource bottlenecks. This localized prompt modification encourages the agent to optimize its actions for efficiency, potentially addressing the latency issue without disrupting the underlying assistant capabilities.", original_content='You are a helpful travel assistant. Use tools when necessary.\n', proposed_content='You are a highly efficient travel assistant. Prioritize speed and use tools when necessary.', evidence_ids=['latency_edge_001'], status=<ProposalStatus.DRAFT: 'draft'>, regression_report=None, created_at=datetime.datetime(2025, 12, 26, 22, 25, 20, 28890), updated_at=datetime.datetime(2025, 12, 26, 22, 25, 20, 28895), metadata={'confidence': 0.8, 'prompt_path': 'artifacts/prompts/prompt_v1.txt', 'tool_schema_path': 'artifacts/tools/tool_schema_v1.json', 'artifact_version_hint': 'v1'}),
#  ImprovementProposal(proposal_id='abb197a6-0724-4ac2-bf9b-572c84922966', type=<ImprovementType.PROMPT: 'prompt'>, cluster_id='adee9cf9-5d72-43eb-a7bc-bbb1ac0f1eed', failure_pattern='The core technical cause is likely an issue with the session management or state retention which prevents the agent from recalling user-provided information across exchanges.', rationale="The proposed change addresses the systemic failure by explicitly instructing the AI agent to manage session state and retain information from previous exchanges. This directive aims to improve the agent's ability to remember user information, thereby enhancing its performance in handling multi-turn dialogues without interfering with its existing functionalities as a helpful travel assistant.", original_content='You are a helpful travel assistant. Use tools when necessary.\n', proposed_content='You are a helpful travel assistant. Use tools when necessary. Ensure to retain and recall user-provided information across exchanges to provide consistently improved assistance.', evidence_ids=['context_loss_001'], status=<ProposalStatus.DRAFT: 'draft'>, regression_report=None, created_at=datetime.datetime(2025, 12, 26, 22, 25, 23, 80277), updated_at=datetime.datetime(2025, 12, 26, 22, 25, 23, 80280), metadata={'confidence': 0.85, 'prompt_path': 'artifacts/prompts/prompt_v1.txt', 'tool_schema_path': 'artifacts/tools/tool_schema_v1.json', 'artifact_version_hint': 'v1'})]

# %%
# Agreement + disagreement checks
feedback_metrics = processor.process_feedback(
    signals=["helpfulness", "coherence", "tool_accuracy"],
    flag_disagreements=True,
)
print("Disagreements:", len(feedback_metrics["disagreements"]))
print("Metrics:", feedback_metrics["metrics"])
# Out:
# Disagreements: 0
# Metrics: {'helpfulness': {'signal': 'helpfulness', 'items': 0, 'annotators': 0, 'pairwise_kappa': None, 'krippendorff_alpha': None}, 'coherence': {'signal': 'coherence', 'items': 0, 'annotators': 0, 'pairwise_kappa': None, 'krippendorff_alpha': None}, 'tool_accuracy': {'signal': 'tool_accuracy', 'items': 0, 'annotators': 0, 'pairwise_kappa': None, 'krippendorff_alpha': None}}

# %%
# Flag items for human review
flagged = processor.flag_for_review(strategy="confidence", limit=10)
print("Flagged for review:", len(flagged))
# Out:
# Flagged for review: 0

# %%
analysis[0].__dict__
# Out:
# {'proposal_id': '49ea292e-628d-4f3d-b31e-c81c4558a3c8',
#  'type': <ImprovementType.PROMPT: 'prompt'>,
#  'cluster_id': 'e20613b6-9e60-4117-a939-b65c2c904be4',
#  'failure_pattern': 'The core technical cause is likely a poor error-handling mechanism that fails to offer corrective suggestions or effective next steps after encountering a date format error.',
#  'rationale': 'The proposed change directly addresses the lack of error handling for date format errors. By instructing the AI to offer users a suggestion on the correct date format and prompting them to re-enter the information, the snippet enhances the user experience by providing clear guidance on how to resolve the issue. This localized change does not alter or disrupt other functionalities of the system prompt.',
#  'original_content': 'You are a helpful travel assistant. Use tools when necessary.\n',
#  'proposed_content': 'You are a helpful travel assistant. Use tools when necessary. If you encounter a date format error, provide the user with a suggestion on the correct date format to use and ask them to enter the date again.',
#  'evidence_ids': ['tool_regression_001',
#   'latency_edge_001',
#   'disagreement_001',
#   'tricky_low_conf_001',
#   'demo_pipeline_1766773293392',
#   'demo_pipeline_1766773293392',
#   'demo_pipeline_1766773415101',
#   'demo_pipeline_1766773415101',
#   'demo_pipeline_1766774333209',
#   'demo_pipeline_1766774333209'],
#  'status': <ProposalStatus.DRAFT: 'draft'>,
#  'regression_report': None,
#  'created_at': datetime.datetime(2025, 12, 26, 22, 24, 59, 929539),
#  'updated_at': datetime.datetime(2025, 12, 26, 22, 24, 59, 929540),
#  'metadata': {'confidence': 0.9,
#   'prompt_path': 'artifacts/prompts/prompt_v1.txt',
#   'tool_schema_path': 'artifacts/tools/tool_schema_v1.json',
#   'artifact_version_hint': 'v1'}}

# %%
flagged
# Out:
# []
